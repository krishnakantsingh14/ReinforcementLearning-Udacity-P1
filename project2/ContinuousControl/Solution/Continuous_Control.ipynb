# %% [markdown]
# # Continuous Control
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.5 which is incompatible.

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726671e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agents while they are training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.0

# %% [markdown]
# When finished, you can close the environment.

# %%
# env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agents while they are training.  However, **_after training the agents_**, you can download the saved model weights to watch the agents on your own machine!

# %%
# %load_ext autoreload
# %autoreload 2
from ddpg_agent import Agent
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
import torch

# %%
  # %reload_ext autoreload

# %%
# agent = Agent(state_size=env_info.vector_observations.shape[1], action_size=brain.vector_action_space_size, random_seed=10)

# %%
# def ddpg(n_episodes=2000, max_t=700):
#     scores_deque = deque(maxlen=100)
#     scores = []
#     max_score = np.Inf
#     for i_episode in range(1, n_episodes+1):
#         env_info = env.reset(train_mode=True)[brain_name]
#         states = env_info.vector_observations
#         agent.reset()
#         score = np.zeros(1)
#         while True:
#             actions = agent.act(states)
#             env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#             next_states = env_info.vector_observations         # get next state (for each agent)
#             rewards = env_info.rewards                         # get reward (for each agent)
#             dones = env_info.local_done                        # see if episode finished
#             agent.step(states, actions, rewards, next_states, dones)
#             score += rewards                      # update the score (for each agent)
#             states = next_states                               # roll over states to next time step
#             if np.any( dones ):                                          # exit loop if episode finished        
#                 break  
#         scores.append(np.mean(score))
#         scores_deque.append(np.mean(score))
        
#         print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f}'.format(i_episode, np.mean(scores_deque), np.mean(score)), end="")
#         if i_episode % 100 == 0:
#             torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
#             torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
#             print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
#         if np.mean(scores_deque) > 30:
#             print (f'Episode: {i_episode} Average Score {np.mean(scores_deque)}, /n, Agent has acheived average score of 30 over 100 consecutive episodes.')
#             torch.save(agent.actor_local.state_dict(), 'solved_actor.pth')
#             torch.save(agent.critic_local.state_dict(), 'solved_critic.pth')
                
#     return scores

# %%
# scores = ddpg()
#

# %%
# fig = plt.figure()
# ax = fig.add_subplot(111)
# plt.plot(np.arange(1, len(scores)+1), scores)
# plt.ylabel('Score')
# plt.xlabel('Episode #')
# plt.show()

# %%
agent = Agent(state_size=env_info.vector_observations.shape[1], action_size=brain.vector_action_space_size, random_seed=0)

# %%
def ddpgwithParameterNoise(n_episodes=2000, max_t=700):
    scores_deque = deque(maxlen=100)
    scores = []
    max_score = np.Inf
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations
        agent.reset()
        score = np.zeros(1)
        while True:
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            agent.step(states, actions, rewards, next_states, dones)
            score += rewards                      # update the score (for each agent)
            states = next_states                               # roll over states to next time step
            if np.any( dones ):                                          # exit loop if episode finished        
                break  
        scores.append(np.mean(score))
        scores_deque.append(np.mean(score))
        
        print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f}'.format(i_episode, np.mean(scores_deque), np.mean(score)), end="")
        if i_episode % 100 == 0:
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)
/n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1182	Average Score: 35.20	Score: 35.72Episode: 1182 Average Score 35.1993992132321, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1183	Average Score: 35.19	Score: 31.82Episode: 1183 Average Score 35.18989921344444, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1184	Average Score: 35.19	Score: 35.33Episode: 1184 Average Score 35.1939992133528, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1185	Average Score: 35.24	Score: 35.27Episode: 1185 Average Score 35.235699212420734, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1186	Average Score: 35.26	Score: 37.72Episode: 1186 Average Score 35.25589921196923, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1187	Average Score: 35.24	Score: 33.04Episode: 1187 Average Score 35.24209921227768, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1188	Average Score: 35.26	Score: 36.81Episode: 1188 Average Score 35.2573992119357, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1189	Average Score: 35.22	Score: 33.33Episode: 1189 Average Score 35.21879921279847, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1190	Average Score: 35.21	Score: 34.11Episode: 1190 Average Score 35.20769921304658, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1191	Average Score: 35.22	Score: 37.18Episode: 1191 Average Score 35.21519921287894, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1192	Average Score: 35.32	Score: 36.79Episode: 1192 Average Score 35.317599210590124, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1193	Average Score: 35.33	Score: 36.04Episode: 1193 Average Score 35.32809921035543, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1194	Average Score: 35.28	Score: 29.08Episode: 1194 Average Score 35.281799211390314, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1195	Average Score: 35.29	Score: 37.55Episode: 1195 Average Score 35.28849921124056, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1196	Average Score: 35.23	Score: 31.84Episode: 1196 Average Score 35.22799921259284, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1197	Average Score: 35.25	Score: 39.43Episode: 1197 Average Score 35.253499212022874, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1198	Average Score: 35.30	Score: 39.40Episode: 1198 Average Score 35.2988992110081, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1199	Average Score: 35.33	Score: 38.13Episode: 1199 Average Score 35.32559921041131, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1200	Average Score: 35.30	Score: 33.34
# Episode: 1200 Average Score 35.29859921101481, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1201	Average Score: 35.27	Score: 32.44Episode: 1201 Average Score 35.265599211752416, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1202	Average Score: 35.26	Score: 36.48Episode: 1202 Average Score 35.26409921178594, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1203	Average Score: 35.28	Score: 35.23Episode: 1203 Average Score 35.27689921149984, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1204	Average Score: 35.27	Score: 36.45Episode: 1204 Average Score 35.26909921167418, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1205	Average Score: 35.28	Score: 38.07Episode: 1205 Average Score 35.27889921145513, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1206	Average Score: 35.28	Score: 36.78Episode: 1206 Average Score 35.281399211399254, /n, Agent has acheived average score of 30 over 100 consecutive episodes.
# Episode 1207	Average Score: 35.26	Score: 35.53Episode: 1207 Average Score 35.25969921188429, /n, Agent has acheived average score of 30 over 100 consecutive episodes.

# %%
agent_test = Agent(state_size, action_size, random_seed = 1)
agent_test.actor_local.load_state_dict(torch.load('solved_actor.pth', map_location = 'cpu'))
agent_test.critic_local.load_state_dict(torch.load('solved_critic.pth', map_location = 'cpu'))

max_t = 1000
env_info = env.reset(train_mode=False)[brain_name]
states = env_info.vector_observations
agent.reset()
score = []

while True:
    actions = agent_test.act(states,add_noise = False)
    env_info = env.step(actions)[brain_name]
    states = env_info.vector_observations
    rewards = env_info.rewards
    dones = env_info.local_done
    score.append(np.mean(rewards))
    if np.any( dones ):                                          # exit loop if episode finished      
        print("Total average score:", np.sum(score) )
        break
# Out:
# Total average score: 33.3999992535
